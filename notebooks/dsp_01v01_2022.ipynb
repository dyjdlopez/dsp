# %% [markdown]
# <a href="https://colab.research.google.com/github/dyjdlopez/dsp/blob/main/notebooks/dsp_01v01_2022.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab 01: Signals and Media
# $_{\text{©D.J. Lopez | 2022 | Digital Signals Processing}}$
#
# Before we get started with manipulating signals, we'll ensure that we can handle digital signals and media through Python. In this laboratory, we will get acquainted with several Python libraries for media processing. Specifically, we will be looking at:
# * NumPy
# * ThinkDSP
# * OpenCV

# %% [markdown]
# # Part 1: One Dimensional Signals

# %%
import numpy as np
import matplotlib.pyplot as plt

t = np.arange(-2*np.pi, 2*np.pi, np.pi/10)
cos_wav = np.cos(t)

# %%
plt.plot(t, cos_wav)
plt.title('Cosine Wave (Continuous)')
plt.xlabel('Period') 
plt.ylabel('Amplitude')
plt.grid()

# %%
plt.stem(t, cos_wav)
plt.title('Coine Wave (Stem Plot)')
plt.xlabel('Period') 
plt.ylabel('Amplitude')
plt.grid()
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ## Audio as 1D Signals

# %%
# !git clone https://github.com/AllenDowney/ThinkDSP.git
# Out:
# Cloning into 'ThinkDSP'...
# remote: Enumerating objects: 2440, done.
# remote: Counting objects: 100% (19/19), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 2440 (delta 9), reused 9 (delta 4), pack-reused 2421
# Receiving objects: 100% (2440/2440), 207.88 MiB | 29.52 MiB/s, done.
# Resolving deltas: 100% (1329/1329), done.
# Checking out files: 100% (302/302), done.

# %%
import os
import sys
sys.path.insert(0, 'ThinkDSP/code/') 
import thinkdsp
import matplotlib.pyplot as pyplot
import IPython

# %%
# This file shows how to generate a sine wave using the ThinkDSP library.
import sys
sys.path.insert(0, 'ThinkDSP/code/') 
import thinkdsp
import IPython

# Generate wave
sin = thinkdsp.SinSignal(freq=400, amp=0.5) # Where freq is the frequency and amp is the amplitude of the sine wave
wave = sin.make_wave(duration=2, start=0, framerate=44100) # Turn the sin wave into an audio wave

# Plot wave
period = sin.period
segment = wave.segment(start=0, duration=period*3)
segment.plot()
pyplot.show()

# Play wave
wave.play()
IPython.display.Audio('sound.wav') # This is required on Google Colab due to compatibility issues
# Out:
# Writing sound.wav
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
wave = thinkdsp.read_wave('test.wav')

wave.plot()
pyplot.show()

# Play audio file
wave.play()
IPython.display.Audio('sound.wav')
# Out:
# Writing sound.wav
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Part 02: 2D Signals

# %%
array_2d = np.ones((5,5))
array_2d[::2, 1::2]=0
array_2d[1::2, ::2]=0

plt.imshow(array_2d, cmap='gray')

# %%
array_2d[::2]*=0.5
plt.imshow(array_2d, cmap='gray')

# %%
int_img = (array_2d*255).astype(int)
int_img
# Out:
# array([[127,   0, 127,   0, 127],
#        [  0, 255,   0, 255,   0],
#        [127,   0, 127,   0, 127],
#        [  0, 255,   0, 255,   0],
#        [127,   0, 127,   0, 127]])

# %% [markdown]
# ## Images as 2D Signals

# %%
import cv2

img = cv2.imread("lenna.png", 0) ## imported as grayscale
plt.imshow(img, cmap='gray')

# %%
img.shape
# Out:
# (512, 512)

# %% [markdown]
# ## Colored Images

# %%
px1 = np.array([[255,0,0]]) #use rgb encoding
px2 = np.array([[0,255,0]])
px3 = np.array([[0,0,255]])

rgb_tensor = np.array([px1, px2, px3])
plt.imshow(rgb_tensor)

# %%
img_color = cv2.imread("lenna.png") 
plt.imshow(img_color)

# %%
img_color = cv2.cvtColor(img_color, cv2.COLOR_BGR2RGB)
plt.imshow(img_color)
